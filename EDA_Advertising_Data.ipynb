# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\hp\Downloads\archive (1)\Advertising_Data.csv")

# %%
df.head()
# Out:
#        TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# 0  281.42      538.80      123.94        349.30                242.77
# 1  702.97      296.53      558.13        180.55                781.06
# 2  313.14      295.94      642.96        505.71                438.91
# 3  898.52       61.27      548.73        240.93                278.96
# 4  766.52      550.72      651.91        666.33                396.33
#
#    Affiliate_Marketing  Product_Sold
# 0               910.10        7164.0
# 1               132.43        5055.0
# 2               464.23        6154.0
# 3               432.27        5480.0
# 4               841.93        9669.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TV                    300 non-null    float64
#  1   Billboards            300 non-null    float64
#  2   Google_Ads            300 non-null    float64
#  3   Social_Media          300 non-null    float64
#  4   Influencer_Marketing  300 non-null    float64
#  5   Affiliate_Marketing   300 non-null    float64
#  6   Product_Sold          300 non-null    float64
# dtypes: float64(7)
# memory usage: 16.5 KB

# %%
df.isnull().sum()
# Out:
# TV                      0
# Billboards              0
# Google_Ads              0
# Social_Media            0
# Influencer_Marketing    0
# Affiliate_Marketing     0
# Product_Sold            0
# dtype: int64

# %%
df.describe()
# Out:
#                TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# count  300.000000  300.000000  300.000000    300.000000            300.000000
# mean   517.431000  502.644933  512.444133    489.800100            465.732567
# std    288.114792  275.842369  285.422376    273.883915            288.314080
# min      1.040000    3.630000   14.860000     11.690000              0.770000
# 25%    273.090000  277.912500  250.530000    265.612500            214.480000
# 50%    513.970000  533.020000  528.965000    486.385000            480.355000
# 75%    774.275000  745.005000  763.345000    695.117500            703.092500
# max    998.100000  995.320000  999.230000    996.160000            999.830000
#
#        Affiliate_Marketing  Product_Sold
# count           300.000000    300.000000
# mean            484.430633   7031.523333
# std             277.955458   1703.614951
# min               6.740000   2259.000000
# 25%             267.677500   5922.500000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.groupby("Social_Media").Product_Sold.mean()
# Out:
# Social_Media
# 11.69      4384.0
# 18.49      7339.0
# 28.84      3473.0
# 29.11      3141.0
# 31.38      7026.0
#            ...
# 970.28    11210.0
# 979.08     8366.0
# 986.35     8169.0
# 992.30    12227.0
# 996.16     9901.0
# Name: Product_Sold, Length: 300, dtype: float64

# %%
pd.pivot_table(data=df,index="Social_Media",values="Product_Sold",aggfunc="mean")
# Out:
#               Product_Sold
# Social_Media
# 11.69               4384.0
# 18.49               7339.0
# 28.84               3473.0
# 29.11               3141.0
# 31.38               7026.0
# ...                    ...
# 970.28             11210.0
# 979.08              8366.0
# 986.35              8169.0
# 992.30             12227.0
# 996.16              9901.0
#
# [300 rows x 1 columns]

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.countplot(x="TV",data=df)

plt.subplot(1,3,2)
sns.countplot(x="Google_Ads",data=df)

plt.subplot(1,3,3)
sns.countplot(x="Influencer_Marketing",data=df)
plt.show()

# %%
df.sample(n=200)
# Out:
#          TV  Billboards  Google_Ads  Social_Media  Influencer_Marketing  \
# 123  775.64      605.60      605.68        189.84                732.13
# 277  858.69      922.49      694.91        121.48                368.16
# 263  920.76      365.45      142.95        416.52                875.27
# 283  640.69      966.63      624.12        948.97                480.16
# 201  668.24      798.99      171.95        283.05                546.02
# ..      ...         ...         ...           ...                   ...
# 256  237.20      299.47      798.66        268.19                100.13
# 60   946.68      429.45      603.51        910.23                479.18
# 194  269.01      390.09      860.02        944.26                607.55
# 216  139.72      831.04      843.23        654.59                325.38
# 113  481.36      142.48      493.66        588.10                784.36
#
#      Affiliate_Marketing  Product_Sold
# 123               923.42        9318.0
# ...

# %%
sns.catplot(data=df,x="Google_Ads",y="Product_Sold",kind="violin")
plt.show()
